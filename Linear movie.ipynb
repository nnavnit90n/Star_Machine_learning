# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
mv=pd.read_csv('C:\\Users\\Admin\\Startech academy\\Files\\movie_collection.csv',header=0)

# %%
mv.head()
# Out:
#    Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0       48000            20.1264               59.62               0.462
# 1       43200            20.5462               69.14               0.531
# 2       69400            20.5458               69.14               0.531
# 3       66800            20.6474               59.36               0.542
# 4       72400            21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# ...

# %%
mv.describe()
# Out:
#           Collection  Marketing expense  Production expense  \
# count     506.000000         506.000000          506.000000
# mean    45057.707510          92.270471           77.273557
# std     18364.351764         172.030902           13.720706
# min     10000.000000          20.126400           55.920000
# 25%     34050.000000          21.640900           65.380000
# 50%     42400.000000          25.130200           74.380000
# 75%     50000.000000          93.541650           91.200000
# max    100000.000000        1799.524000          110.480000
#
#        Multiplex coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          506.000000    506.000000    506.000000          506.000000
# mean             0.445305  34911.144022    142.074901            8.014002
# std              0.115878   3903.038232     28.148861            1.054266
# min              0.129000  19781.355000     76.400000            3.840000
# ...

# %%
mv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 20 columns):
# Collection             506 non-null int64
# Marketing expense      506 non-null float64
# Production expense     506 non-null float64
# Multiplex coverage     506 non-null float64
# Budget                 506 non-null float64
# Movie_length           506 non-null float64
# Lead_ Actor_Rating     506 non-null float64
# Lead_Actress_rating    506 non-null float64
# Director_rating        506 non-null float64
# Producer_rating        506 non-null float64
# Critic_rating          506 non-null float64
# Trailer_views          506 non-null int64
# 3D_available           506 non-null object
# Time_taken             494 non-null float64
# Twitter_hastags        506 non-null float64
# Genre                  506 non-null object
# Avg_age_actors         506 non-null int64
# MPAA_film_rating       506 non-null object
# Num_multiplex          506 non-null int64
# ...

# %%
mv=mv.rename(columns={'Marketing expense':'Marketing_expense','Production expense':'Production_expense'})

# %%
mv.head()
# Out:
#    Collection  Marketing_expense  Production_expense  Multiplex coverage  \
# 0       48000            20.1264               59.62               0.462
# 1       43200            20.5462               69.14               0.531
# 2       69400            20.5458               69.14               0.531
# 3       66800            20.6474               59.36               0.542
# 4       72400            21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# ...

# %%
sns.jointplot(x='Marketing_expense',y='Collection',data=mv)

# %%
sns.jointplot(x='Production_expense',y='Collection',data=mv)

# %%
sns.boxplot(x='Marketing_expense',data=mv)

# %%
mv.head()
# Out:
#    Collection  Marketing_expense  Production_expense  Multiplex coverage  \
# 0       48000            20.1264               59.62               0.462
# 1       43200            20.5462               69.14               0.531
# 2       69400            20.5458               69.14               0.531
# 3       66800            20.6474               59.36               0.542
# 4       72400            21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# ...

# %%
sns.countplot(x='3D_available',data=mv)

# %%
sns.countplot(x='Genre',data=mv)

# %%
sns.countplot(x='MPAA_film_rating',data=mv)

# %%
# There are missing value in time taken
#there are putlier in msrketing_expense

# %% [markdown]
# # Outlier Treating

# %%
np.percentile(mv.Marketing_expense,[99])
# Out:
# array([847.4066])

# %%
np.percentile(mv.Marketing_expense,[99])[0]
# Out:
# 847.4065999999991

# %%
uv=np.percentile(mv.Marketing_expense,[99])[0]

# %%
mv[(mv.Marketing_expense>uv)]
# Out:
#      Collection  Marketing_expense  Production_expense  Multiplex coverage  \
# 380       20800           1799.524                91.2               0.329
# 404       17000            850.584                91.2               0.307
# 405       10000           1378.416                91.2               0.307
# 410       30000           1042.716                91.2               0.403
# 414       14000            934.922                91.2               0.307
# 418       17600           1490.682                91.2               0.321
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 380  38707.240         165.4               9.170                9.430
# 404  30724.705         158.9               9.050                9.220
# 405  31569.065         173.5               9.235                9.405
# 410  31980.135         173.5               9.155                9.340
# 414  25103.045         173.5               9.130                9.250
# ...

# %%
mv.Marketing_expense[(mv.Marketing_expense>3*uv)]=3*uv
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
mv[(mv.Marketing_expense>uv)]
# Out:
#      Collection  Marketing_expense  Production_expense  Multiplex coverage  \
# 380       20800           1799.524                91.2               0.329
# 404       17000            850.584                91.2               0.307
# 405       10000           1378.416                91.2               0.307
# 410       30000           1042.716                91.2               0.403
# 414       14000            934.922                91.2               0.307
# 418       17600           1490.682                91.2               0.321
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 380  38707.240         165.4               9.170                9.430
# 404  30724.705         158.9               9.050                9.220
# 405  31569.065         173.5               9.235                9.405
# 410  31980.135         173.5               9.155                9.340
# 414  25103.045         173.5               9.130                9.250
# ...

# %%
np.percentile(mv.Marketing_expense,[1])
# Out:
# array([20.27221])

# %%
np.percentile(mv.Marketing_expense,[1])[0]
# Out:
# 20.27221

# %%
lv=np.percentile(mv.Marketing_expense,[1])[0]

# %%
mv[(mv.Marketing_expense)<lv]
# Out:
#      Collection  Marketing_expense  Production_expense  Multiplex coverage  \
# 0         48000            20.1264               59.62               0.462
# 54        37800            20.2720               63.00               0.590
# 55        70800            20.2622               57.44               0.597
# 284       64400            20.1812               60.94               0.600
# 285       44000            20.2192               59.50               0.611
# 341       65400            20.2602               58.04               0.558
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0    36524.125         138.7               7.825                8.095
# 54   32707.840         121.1               6.300                6.365
# 55   40268.195          95.4               5.550                5.795
# 284  39373.840          94.3               6.280                6.500
# 285  35846.415         105.4               6.335                6.445
# ...

# %%
mv.Marketing_expense
# Out:
# 0      20.1264
# 1      20.5462
# 2      20.5458
# 3      20.6474
# 4      21.3810
#         ...
# 501    21.2526
# 502    20.9054
# 503    21.2152
# 504    22.1918
# 505    20.9482
# Name: Marketing_expense, Length: 506, dtype: float64

# %%
#IQR = mv.Marketing_expense.quantile(0.75) - mv.Marketing_expense.quantile(0.25)

# %%
#upper_limit = mv.Marketing_expense.quantile(0.75) + (IQR * 1.5)
#upper_limit_extreme = mv.Marketing_expense.quantile(0.75) + (IQR * 3)
#upper_limit, upper_limit_extreme

# %%
#index= mv[(mv['Marketing_expense'] >= 309.2439)].index
#mv.drop(index, inplace=True)

# %%
#sns.jointplot(x='Marketing_expense',y='Collection',data=mv)

# %%
#sns.boxplot(x='Marketing_expense',data=mv)

# %% [markdown]
# # Missing Imputation

# %%
mv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 20 columns):
# Collection             506 non-null int64
# Marketing_expense      506 non-null float64
# Production_expense     506 non-null float64
# Multiplex coverage     506 non-null float64
# Budget                 506 non-null float64
# Movie_length           506 non-null float64
# Lead_ Actor_Rating     506 non-null float64
# Lead_Actress_rating    506 non-null float64
# Director_rating        506 non-null float64
# Producer_rating        506 non-null float64
# Critic_rating          506 non-null float64
# Trailer_views          506 non-null int64
# 3D_available           506 non-null object
# Time_taken             494 non-null float64
# Twitter_hastags        506 non-null float64
# Genre                  506 non-null object
# Avg_age_actors         506 non-null int64
# MPAA_film_rating       506 non-null object
# Num_multiplex          506 non-null int64
# ...

# %%
mv.Time_taken=mv.Time_taken.fillna(mv.Time_taken.mean())

# %%
mv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 20 columns):
# Collection             506 non-null int64
# Marketing_expense      506 non-null float64
# Production_expense     506 non-null float64
# Multiplex coverage     506 non-null float64
# Budget                 506 non-null float64
# Movie_length           506 non-null float64
# Lead_ Actor_Rating     506 non-null float64
# Lead_Actress_rating    506 non-null float64
# Director_rating        506 non-null float64
# Producer_rating        506 non-null float64
# Critic_rating          506 non-null float64
# Trailer_views          506 non-null int64
# 3D_available           506 non-null object
# Time_taken             506 non-null float64
# Twitter_hastags        506 non-null float64
# Genre                  506 non-null object
# Avg_age_actors         506 non-null int64
# MPAA_film_rating       506 non-null object
# Num_multiplex          506 non-null int64
# ...

# %%
mv['avg_rating']=(mv.Director_rating+mv.Producer_rating+mv.Critic_rating)/3

# %%
mv.head()
# Out:
#    Collection  Marketing_expense  Production_expense  Multiplex coverage  \
# 0       48000            20.1264               59.62               0.462
# 1       43200            20.5462               69.14               0.531
# 2       69400            20.5458               69.14               0.531
# 3       66800            20.6474               59.36               0.542
# 4       72400            21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  ...  Trailer_views  3D_available  \
# ...

# %%
del mv['Producer_rating']

# %%
del mv['Director_rating']

# %%
del mv['Critic_rating']

# %%
mv.head()
# Out:
#    Collection  Marketing_expense  Production_expense  Multiplex coverage  \
# 0       48000            20.1264               59.62               0.462
# 1       43200            20.5462               69.14               0.531
# 2       69400            20.5458               69.14               0.531
# 3       66800            20.6474               59.36               0.542
# 4       72400            21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Trailer_views 3D_available  Time_taken  Twitter_hastags     Genre  \
# ...

# %%
mv.shape
# Out:
# (506, 18)

# %%
mv=pd.get_dummies(mv)

# %%
mv.head()
# Out:
#    Collection  Marketing_expense  Production_expense  Multiplex coverage  \
# 0       48000            20.1264               59.62               0.462
# 1       43200            20.5462               69.14               0.531
# 2       69400            20.5458               69.14               0.531
# 3       66800            20.6474               59.36               0.542
# 4       72400            21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Trailer_views  Time_taken  ...  Num_multiplex  Start_Tech_Oscar  \
# ...

# %%
del mv['3D_available_NO']

# %%
del mv['Genre_Thriller']

# %%
mv.head()
# Out:
#    Collection  Marketing_expense  Production_expense  Multiplex coverage  \
# 0       48000            20.1264               59.62               0.462
# 1       43200            20.5462               69.14               0.531
# 2       69400            20.5458               69.14               0.531
# 3       66800            20.6474               59.36               0.542
# 4       72400            21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Trailer_views  Time_taken  Twitter_hastags  Avg_age_actors  Num_multiplex  \
# ...

# %%
mv.shape
# Out:
# (506, 20)

# %%
mv.corr()
# Out:
#                      Collection  Marketing_expense  Production_expense  \
# Collection             1.000000          -0.389582           -0.484754
# Marketing_expense     -0.389582           1.000000            0.406583
# Production_expense    -0.484754           0.406583            1.000000
# Multiplex coverage     0.429300          -0.420972           -0.763651
# Budget                 0.696304          -0.219247           -0.391676
# Movie_length          -0.377999           0.352734            0.644779
# Lead_ Actor_Rating    -0.251355           0.380050            0.706481
# Lead_Actress_rating   -0.249459           0.379813            0.707956
# Trailer_views          0.720119          -0.443457           -0.591657
# Time_taken             0.110005           0.025694            0.015773
# Twitter_hastags        0.023122           0.013518           -0.000839
# Avg_age_actors        -0.047426           0.059204            0.055810
# ...

# %%
del mv['Lead_ Actor_Rating']

# %%
del mv['Lead_Actress_rating']

# %%
mv.head()
# Out:
#    Collection  Marketing_expense  Production_expense  Multiplex coverage  \
# 0       48000            20.1264               59.62               0.462
# 1       43200            20.5462               69.14               0.531
# 2       69400            20.5458               69.14               0.531
# 3       66800            20.6474               59.36               0.542
# 4       72400            21.3810               59.36               0.542
#
#       Budget  Movie_length  Trailer_views  Time_taken  Twitter_hastags  \
# 0  36524.125         138.7         527367      109.60          223.840
# 1  35668.655         152.4         494055      146.64          243.456
# 2  39912.675         134.6         547051      147.88         2022.400
# 3  38873.890         119.3         516279      185.36          225.344
# 4  39701.585         127.7         531448      176.48          225.792
#
#    Avg_age_actors  Num_multiplex  Start_Tech_Oscar  avg_rating  \
# ...

# %%
mv.shape
# Out:
# (506, 18)
