# %% [markdown]
# # Importing all the library

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Data Dictionary
# poor_prop : proporton of poor popuation in the town
#
# airport : Is there an airport in the city
#
# n_hos_beds : No of hospitall beds on 1000 poopulation in the town
#
# n_hots_roomss : No of htels rooms on 1000 poopulation in the town
#
# waterbody : What type of natural water type source is there ( River/Lake/Both /None)
#
# rainfall : The average rainfall i centimrters
#
# bus_ter: Is there bus teriminal in city or not?
#
#
# parks: Proportion of land assinged as a parks and green areas in the town.

# %%
# Load the house price data set
hp=pd.read_csv('C:\\Users\\Admin\\Startech academy\\Files\\Linear house.csv',header=0)

# %%
# It will display the top 5 Data of data set
hp.head()
hp.tail()# It will display from bottom data set
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 501   2.76   2.06      19.0       9.67      NO       9.348      12.1792
# 502   2.46   2.14      19.0       9.08     YES       6.612      13.1648
# 503   2.29   1.98      19.0       5.64      NO       5.478      12.1912
# 504   2.40   2.31      19.0       6.48     YES       7.940      15.1760
# 505   2.64   2.42      19.0       7.88     YES      10.280      10.1520
#
#           waterbody  rainfall bus_ter     parks
# ...

# %%
# It describe about te data
hp.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677082   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
# It gives the information of data that data type, is there any null value 
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# price          506 non-null float64
# crime_rate     506 non-null float64
# resid_area     506 non-null float64
# air_qual       506 non-null float64
# room_num       506 non-null float64
# age            506 non-null float64
# dist1          506 non-null float64
# dist2          506 non-null float64
# dist3          506 non-null float64
# dist4          506 non-null float64
# teachers       506 non-null float64
# poor_prop      506 non-null float64
# airport        506 non-null object
# n_hos_beds     498 non-null float64
# n_hot_rooms    506 non-null float64
# waterbody      506 non-null object
# rainfall       506 non-null int64
# bus_ter        506 non-null object
# parks          506 non-null float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %%
# Graphical representaion of data using seaborn
sns.jointplot(x='n_hot_rooms',y='price',data=hp) 
# HERE WE CAN CHECK THE OUTLIER THE DOTS ARE REPRESENTING THE OUTLIER

# %%
# Boxplot to check the outlier
sns.boxplot(x='n_hot_rooms',data=hp)

# %%
sns.jointplot(x='rainfall',y='price',data=hp)

# %%
sns.boxplot(x='rainfall',data=hp)

# %%
hp.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
#Counterplot for the non numerical type label
sns.countplot(x='airport',data=hp)

# %%
# Ccounterplot for non numerical labels
sns.countplot(x='waterbody',data=hp)

# %%
sns.countplot(x='bus_ter',data=hp)

# %%
#there are missing values in n_hos_bed  
# by using (hp.info) i have got the idea of missing value 
#There are outlier in n_hot_rooms, rainfall area
# Idea of outlier we got by Boxplot, Jointplot or describe function also

# %% [markdown]
# # Outlier treatment:
# Outlier is a terminology commonly used by data scientist and analytics , Outlier is an oberservation which appear far away and diverge from alll over pattern is simple.
# # Reason:
# 1.Data Entry Error
#
# 2.Measurement Occurs
#
# 3.Sampling Error
# # Impact
# 1.It increases the error variance and reduce the power of statistial test
# # Solution:
# 1.Solution detect outlier by EDA and graphical way
#
# 2.Impute outliers
#
# # Outlier Treatment
# 1.Capping and folding method: Impute all value above 3* P99 and below 0.3* P1
#
# .Impute with values of 3 * P99 and 0.3*P1
#
# .You can use any multiplier intead of 3 as per our buisness requirement.
#
# 2.Exponential smoothing:
#
# 3.Sigma Approach:
#
# 4.Z score
#
# 5.Interquartile range

# %%
# we are using the percentile function so we want the 99 percentile
np.percentile(hp.n_hot_rooms,[99])
# The 99 percentile of n_hot_rooms is an array which is 15.399
# Out:
# array([15.39952])

# %%
# If we want to specify the location of that value we will locate that value
np.percentile(hp.n_hot_rooms,[99])[0]
# fetching the first value of an array
# Out:
# 15.399519999999999

# %%
#Saving the 15.399 value in another variable that is uv
uv=np.percentile(hp.n_hot_rooms,[99])[0]

# %%
# How to identify that row whos value is more than this value
hp[(hp.n_hot_rooms)>uv]
# here we will get all the value whose value is greater than 15.399
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
# we can limit the value n_hots_rooms
hp.n_hot_rooms[(hp.n_hot_rooms)>3*uv]=3*uv
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
hp[(hp.n_hot_rooms)>uv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 166   2.31   1.86      25.3       3.70     YES       8.300     15.40000
# 204   5.28   4.99      25.3       2.88     YES       8.900     15.40000
# 267   2.43   2.52      27.0       7.44     YES       8.000     15.40000
# 369   1.65   0.94      19.8       3.73     YES       6.700     15.40000
# ...

# %%
np.percentile(hp.rainfall,[1])
# Here want the first value of an array
# Out:
# array([20.])

# %%
np.percentile(hp.rainfall,[1])[0]
# value of the array
# Out:
# 20.0

# %%
# Storing the first percentile value of an array
lv=np.percentile(hp.rainfall,[1])[0]

# %%
hp[(hp.rainfall)<lv]
# If any value which is less than 20.
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         3     YES  0.044019

# %%
#For lower value we ll multiply with 0.3
hp.rainfall[(hp.rainfall)<0.3*lv]=0.3*lv
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
hp[(hp.rainfall)<lv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         6     YES  0.044019

# %% [markdown]
# # Using inter quartile to  range  to detect and remove the  it fro data by dropping

# %%
#IQR = hp.n_hot_rooms.quantile(0.75) - hp.n_hot_rooms.quantile(0.25)

# %%
#upper_limit = hp.n_hot_rooms.quantile(0.75) + (IQR * 1.5)
#upper_limit_extreme =hp.n_hot_rooms.quantile(0.75) + (IQR * 3)
#upper_limit, upper_limit_extreme

# %%
#index= hp[(hp['n_hot_rooms'] >=23.1138)].index
#hp.drop(index, inplace=True)

# %%
#sns.jointplot(x='n_hot_rooms',y='price',data=hp) 
# HERE WE CAN CHECK THE OUTLIER THE DOTS ARE REPRESENTING THE OUTLIER

# %%
sns.jointplot(x='crime_rate',y='price',data=hp)

#Polynomial relation ship

# %% [markdown]
# # Missing value imputation

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# price          506 non-null float64
# crime_rate     506 non-null float64
# resid_area     506 non-null float64
# air_qual       506 non-null float64
# room_num       506 non-null float64
# age            506 non-null float64
# dist1          506 non-null float64
# dist2          506 non-null float64
# dist3          506 non-null float64
# dist4          506 non-null float64
# teachers       506 non-null float64
# poor_prop      506 non-null float64
# airport        506 non-null object
# n_hos_beds     498 non-null float64
# n_hot_rooms    506 non-null float64
# waterbody      506 non-null object
# rainfall       506 non-null int64
# bus_ter        506 non-null object
# parks          506 non-null float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %%
hp.n_hos_beds=hp.n_hos_beds.fillna(hp.n_hos_beds.mean())

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# price          506 non-null float64
# crime_rate     506 non-null float64
# resid_area     506 non-null float64
# air_qual       506 non-null float64
# room_num       506 non-null float64
# age            506 non-null float64
# dist1          506 non-null float64
# dist2          506 non-null float64
# dist3          506 non-null float64
# dist4          506 non-null float64
# teachers       506 non-null float64
# poor_prop      506 non-null float64
# airport        506 non-null object
# n_hos_beds     506 non-null float64
# n_hot_rooms    506 non-null float64
# waterbody      506 non-null object
# rainfall       506 non-null int64
# bus_ter        506 non-null object
# parks          506 non-null float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %%
# to fill all the data which are empty
#hp.hp.fillna(hp.mean()) 
# but it will fill only numerical type data

# %%
sns.jointplot(x='crime_rate',y='price',data=hp)

# %%
#Here you see the ploynomial relationship with Y, For the low rime rate the price is high and for high crime rate the price is low

# %%
# Removing the outlier by transforming
#By using log function with crime_rate we get the linear relationship with y variable
hp.crime_rate=np.log(1+hp.crime_rate)

# %%
sns.jointplot(x='crime_rate',y='price',data=hp)
# Now we get the linear plot

# %%
hp['avg_dist']=(hp.dist1+hp.dist2+hp.dist3+hp.dist4)/4
# avg dist representing the sense of all the four dist

# %%
hp.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480     11.19200
# 1   5.12   5.06      22.2       9.14      NO       7.332     12.17280
# 2   5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 3   6.16   5.96      21.3       2.94     YES       9.268     11.26720
# 4   6.37   5.86      21.3       5.33      NO       8.824     11.28960
#
#   waterbody  rainfall bus_ter     parks  avg_dist
# 0     River        23     YES  0.049347    4.0875
# ...

# %%
del hp['dist1']

# %%
del hp['dist2']

# %%
del hp['dist3']

# %%
del hp['dist4']

# %%
hp.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.544466   12.653063    7.899767    12.864050   39.187747
# ...

# %%
hp=pd.get_dummies(hp)

# %%
hp.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_NO  airport_YES  waterbody_Lake  waterbody_Lake and River  \
# ...

# %%
del hp['airport_NO']

# %%
del hp['waterbody_None']

# %%
hp.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_River  \
# ...

# %% [markdown]
# # Correlation Analysis

# %%
hp.corr()
# How to understand this correlation because it is very important for buisness solution
#By this we can get the correlation between two variables
#We are trying to identify high and low correlation
# High correlation between two independent variables leads to the problem
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.466527   -0.484754 -0.429300
# crime_rate               -0.466527    1.000000    0.660283  0.707587
# resid_area               -0.484754    0.660283    1.000000  0.763651
# air_qual                 -0.429300    0.707587    0.763651  1.000000
# room_num                  0.696304   -0.288784   -0.391676 -0.302188
# age                      -0.377999    0.559591    0.644779  0.731470
# teachers                  0.505655   -0.390052   -0.383248 -0.188933
# poor_prop                -0.740836    0.608970    0.603800  0.590879
# n_hos_beds                0.108880   -0.004089    0.005799 -0.049553
# n_hot_rooms               0.017007    0.056570   -0.003761  0.007238
# rainfall                 -0.047200    0.082151    0.055845  0.091956
# parks                    -0.391574    0.638951    0.707635  0.915544
# avg_dist                  0.249289   -0.586371   -0.708022 -0.769247
# ...

# %%
del hp['parks']

# %%
hp.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  \
# 0       4.98       5.480     11.19200        23    4.0875            1
# 1       9.14       7.332     12.17280        42    4.9675            0
# 2       4.03       7.394     46.19856        38    4.9675            0
# 3       2.94       9.268     11.26720        45    6.0650            1
# 4       5.33       8.824     11.28960        55    6.0625            0
#
#    waterbody_Lake  waterbody_Lake and River  waterbody_River  bus_ter_YES
# ...

# %% [markdown]
# # Linear Regression
# A Supervised Learning Algorithm that learns from a set of training samples
# “Linear Regression” is a statistical method to regress the data with dependent variable having
# continuous values whereas independent variables can have either continuous or categorical
# values. In other words “Linear Regression” is a method to predict dependent variable (Y) based
# on values of independent variables (X).
#
# It can be used for the cases where we want to predict some continuous quantity. E.g.,
# Predicting traffic in a retail store, predicting a user’s dwell time or number of pages visited on
# Dezyre.com etc.

# %%
# Linear Regression:is a model approach relationship approach between one dependent and more than one independent variale.
# Q. How accurately i can predict the price of the house, given value of all variables.
#Q.  How accurately we can estimate the effect of each of these variables on the house price

# %%
# Simple Linear Regression is the approach of predicting the dependent variable on single independent varibale
# Acessing Model Accuracy using RSE(Residual Standard Eror) and Rsquared
#RSE is the average amount which will deviate from true regrssion Line
#RSq provide absolute lack of fit of the model

# %%
import statsmodels.api as sm

# %%
X=sm.add_constant(hp['room_num']) # Creating BEta nod
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
X.head()
# Out:
#    const  room_num
# 0    1.0     6.575
# 1    1.0     6.421
# 2    1.0     7.185
# 3    1.0     6.998
# 4    1.0     7.147

# %%
# to fit the model we will cretae the obejct  # OLS ordinary least square
lm=sm.OLS(hp['price'],X).fit()

# %%
lm.summary()
#''' Const is betenod  and room_num is betaone'''
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     474.3
# Date:                Mon, 04 Jan 2021   Prob (F-statistic):           1.31e-74
# Time:                        19:19:11   Log-Likelihood:                -1671.6
# No. Observations:                 506   AIC:                             3347.
# Df Residuals:                     504   BIC:                             3356.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6592      2.642    -13.118      0.000     -39.850     -29.468
# ...

# %% [markdown]
# # Most commonly used method in Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
y=hp['price']

# %%
X=hp[['room_num']]

# %%
lm2=LinearRegression()

# %%
lm2.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm2.intercept_)# Beta nod
print(lm2.coef_)  # Beta one
# Out:
# -34.65924312309721
# [9.09966966]

# %%
help(lm2)
# Out:
# Help on LinearRegression in module sklearn.linear_model.base object:
#
# class LinearRegression(LinearModel, sklearn.base.RegressorMixin, sklearn.base.MultiOutputMixin)
#  |  LinearRegression(fit_intercept=True, normalize=False, copy_X=True, n_jobs=None)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : boolean, optional, default True
#  |      whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (e.g. data is expected to be already centered).
#  |
#  |  normalize : boolean, optional, default False
#  |      This parameter is ignored when ``fit_intercept`` is set to False.
#  |      If True, the regressors X will be normalized before regression by
#  |      subtracting the mean and dividing by the l2-norm.
#  |      If you wish to standardize, please use
#  |      :class:`sklearn.preprocessing.StandardScaler` before calling ``fit`` on
# ...

# %%
lm2.predict(X)
# Out:
# array([25.17108491, 23.76973578, 30.72188341, 29.02024518, 30.37609596,
#        23.85163281, 20.04797089, 21.50391804, 16.58099675, 19.97517353,
#        23.36935032, 20.02067188, 18.92871152, 19.4746917 , 20.81234314,
#        18.42822969, 19.34729633, 19.84777816, 14.98855456, 17.45456504,
#        16.0259169 , 19.62028642, 21.23092795, 18.23713663, 19.24719996,
#        16.28980732, 18.23713663, 20.36645933, 24.44311134, 26.07195221,
#        17.32716966, 20.59395107, 19.48379137, 17.21797363, 20.81234314,
#        19.32909699, 18.49192738, 18.57382441, 19.62938609, 25.3530783 ,
#        29.25683659, 26.9455205 , 21.47661903, 21.85880515, 20.56665206,
#        17.0450799 , 17.99144555, 20.21176495, 14.46987339, 16.31710633,
#        19.60208708, 20.98523687, 24.58870605, 19.92057552, 18.91961185,
#        31.30426226, 23.42394834, 27.3641053 , 21.25822696, 19.27449897,
#        17.58196041, 19.62938609, 24.08822422, 26.87272314, 29.98481016,
# ...

# %%
import seaborn as sns
sns.jointplot(x=hp['room_num'],y=hp['price'],data=hp,kind='reg')
#the line is passing is regression line

# %% [markdown]
# # Multipe Linear Regression

# %%
# Using statsmodel

# %%
X_multi=hp.drop('price',axis=1) # Independent

# %%
X_multi.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0    0.006300       32.31     0.538     6.575  65.2      24.7       4.98
# 1    0.026944       37.07     0.469     6.421  78.9      22.2       9.14
# 2    0.026924       37.07     0.469     7.185  61.1      22.2       4.03
# 3    0.031857       32.18     0.458     6.998  45.8      21.3       2.94
# 4    0.066770       32.18     0.458     7.147  54.2      21.3       5.33
#
#    n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  waterbody_Lake  \
# 0       5.480     11.19200        23    4.0875            1               0
# 1       7.332     12.17280        42    4.9675            0               1
# 2       7.394     46.19856        38    4.9675            0               0
# 3       9.268     11.26720        45    6.0650            1               1
# 4       8.824     11.28960        55    6.0625            0               1
#
#    waterbody_Lake and River  waterbody_River  bus_ter_YES
# ...

# %%
y_multi=hp['price'] # Dependend

# %%
y_multi.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: price, dtype: float64

# %%
# Lets add a constant beta nod
X_multi_cons=sm.add_constant(X_multi)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
X_multi_cons.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0    0.006300       32.31     0.538     6.575  65.2      24.7       4.98
# 1    0.026944       37.07     0.469     6.421  78.9      22.2       9.14
# 2    0.026924       37.07     0.469     7.185  61.1      22.2       4.03
# 3    0.031857       32.18     0.458     6.998  45.8      21.3       2.94
# 4    0.066770       32.18     0.458     7.147  54.2      21.3       5.33
#
#    n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  waterbody_Lake  \
# 0       5.480     11.19200        23    4.0875            1               0
# 1       7.332     12.17280        42    4.9675            0               1
# 2       7.394     46.19856        38    4.9675            0               0
# 3       9.268     11.26720        45    6.0650            1               1
# 4       8.824     11.28960        55    6.0625            0               1
#
#    waterbody_Lake and River  waterbody_River  bus_ter_YES
# ...

# %%
# object 
lm_multi=sm.OLS(y_multi,X_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     84.34
# Date:                Mon, 04 Jan 2021   Prob (F-statistic):          4.19e-125
# Time:                        19:19:58   Log-Likelihood:                -1516.6
# No. Observations:                 506   AIC:                             3065.
# Df Residuals:                     490   BIC:                             3133.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
# Rsq value is 0.71 is pretty good
#Prob Fstatistic is very low it gives confidence that our independent variable have some impact on dependent variable
#Total no of observation is 506
#df is degree of fredom is 490
# Coeff is the value of beta one#
#Std Error
# The lower the p value more significant of dtermining the Y eg( air qual, room_num,taechers,poor propagation,avg_dist)These are the variable which have highest imapct on y variable.
#In coeef if the sign is positive the we are inreasing the independent te dependent variable aare increasing
#
#

# %% [markdown]
# # Regression Model Performance
# Once you build the model, the next logical question comes in mind is to know whether your
# model is good enough to predict in future or the relationship which you built between
# dependent and independent variables is good enough or not.
#
# For this purpose there are various metrics which we look into
# 1.R- square:
#
# Total Sum of Squares (TSS) : TSS is a measure of total variance in the response/
# dependent variable Y and can be thought of as the amount of variability inherent in the
# response before the regression is performed.
#
# Residual Sum of Squares (RSS) : RSS measures the amount of variability that is left
# unexplained after performing the regression.
#
# (TSS – RSS) measures the amount of variability in the response that is explained (or
# removed) by performing the regression
# Where N is the number of observations used to fit the model, σx is the standard
# deviation of x, and σy is the standard deviation of y.
#
#
# ranges from 0 to 1.
#
#  0 means that the dependent variable cannot be predicted from the independent
# variable
#
# 1 means the dependent variable can be predicted without error from the
# independent variable

# %% [markdown]
# #
# 2.ROOT MEAN SQUARE
#
# Though RMSE is a good measure for errors but the issue with it is that it is susceptible to
# the range of your dependent variable. If your dependent variable has thin range, your
# RMSE will be low and if dependent variable has wide range RMSE will be high. Hence,
# RMSE is a good metric to compare between different iterations of a model.

# %%
#Object
lm3=LinearRegression()

# %%
lm3.fit(X_multi,y_multi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm3.intercept_)
print(lm3.coef_)
#we can compre this with statsmodels
# Out:
# -6.4986251984199335
# [ 9.70998193e-03 -4.08746495e-02 -1.58973999e+01  4.01901676e+00
#  -5.71475069e-03  1.00700068e+00 -5.77271243e-01  3.29221139e-01
#   9.18675603e-02  1.61185504e-02 -1.21863952e+00  1.13151586e+00
#   2.64086064e-01 -6.87555889e-01 -2.91318712e-01  0.00000000e+00]

# %% [markdown]
# # How to spit train test data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_multi,y_multi,test_size=0.2,random_state=0)
# test_size 20% data
# Random_state =1 eery time train test will get the same sample

# %%
print(X_train.shape)
# Out:
# (404, 16)

# %%
print(y_train.shape)
# Out:
# (404,)

# %%
#80% are in trainning set

# %%
lm_a=LinearRegression()

# %%
lm_a.fit(X_train,y_train)# fit our model on training set
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Now let get the predicted value of test set
y_test_a=lm_a.predict(X_test)

# %%
#Now let get the predicted value of train set
y_train_a=lm_a.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_test_a)
# Out:
# 0.5496468288205676

# %%
r2_score(y_train,y_train_a)
# Out:
# 0.756463540591123
